# %%
#Install dependencies
# %pip install anthropic python-dotenv

# %%
#Load env variables
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
#Create API client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-5"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    return message.content[0].text

# %%
# Start with an empty message list
messages = []

# Add the initial user question
add_user_message(messages, "Defini la computacion cuatica en una sentencia")

# Get Claude's response
answer = chat(messages)

# Add Claude's response to the conversation history
add_assistant_message(messages, answer)

# Add a follow-up question
add_user_message(messages, "Escribi otra sentencia")

# Get the follow-up response with full context
final_answer = chat(messages)

# %%
answer
# Out:
# 'La computación cuántica es un paradigma de cómputo que utiliza principios de la mecánica cuántica —como la superposición y el entrelazamiento— para procesar información mediante qubits, permitiendo resolver ciertos problemas de manera potencialmente más eficiente que las computadoras clásicas.'

# %%
final_answer
# Out:
# 'La computación cuántica aprovecha fenómenos cuánticos, como la superposición de estados y el entrelazamiento entre partículas, para representar y manipular información en unidades llamadas qubits, en lugar de los bits clásicos que solo pueden estar en 0 o 1.'
