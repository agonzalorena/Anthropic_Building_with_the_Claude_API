# %%
# Load env variables and create API client
from dotenv import load_dotenv

load_dotenv()


from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages,system=None, temperature=1.0): # temperature 0.0 - 1.0
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
    }
    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message
    #for block in message.content:
    #   if block.type == "text":
    #        return block.text

# %%
# El parametro temperature esta deprecado: https://platform.claude.com/docs/en/api/messages/create
# Ahora se usa el parametro Thinking y effort:
# https://platform.claude.com/docs/en/build-with-claude/extended-thinking|
# https://platform.claude.com/docs/en/build-with-claude/effort
"""
def chat(messages, system=None, effort=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "thinking": {"type": "adaptive"},
    }
    if system:
        params["system"] = system
    if effort:
        params["effort"] = effort  # "low" | "medium" | "high" | "max"

    message = client.messages.create(**params)
    for block in message.content:
        if block.type == "text":
            return block.text
"""
# Out:
# Message(id='msg_011CeVrjMRTpFF8d3nuj58r3', container=None, content=[TextBlock(citations=None, text='Un anciano relojero descubre que puede reparar no solo relojes, sino también los momentos rotos de las personas que se los llevan, hasta que un día encuentra un reloj que perteneció a su propio hijo desaparecido años atrás.', type='text')], model='claude-sonnet-5', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='global', input_tokens=25, output_tokens=83, output_tokens_details=OutputTokensDetails(thinking_tokens=0), server_tool_use=None, service_tier='standard'))
